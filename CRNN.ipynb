# %% [markdown]
# # ECOQCODE OCR CRNN Model Training

# %% [markdown]
# ## 1. Data Generation (for OCR)

# %%
import os
import random
import string
from PIL import Image, ImageDraw, ImageFont
from pathlib import Path

# Configuration
bg_dir = './real_backgrounds'
out_dir = './eco_dataset/images'
label_file = './eco_dataset/labels.txt'
font_path = 'arial.ttf'  # Make sure this font is available or change the path
correct_text = 'ECOQCODE'
num_samples = 1500  # Number of images to generate
image_size = (648, 648)  # Output image size
noise_ratio = 0.33 # Ratio of noisy images to total images

noise_chars = string.ascii_uppercase + string.digits
noise_chars = noise_chars.replace('E', '').replace('C', '').replace('O', '').replace('Q', '').replace('D', '')  # Remove characters from the text

os.makedirs(out_dir, exist_ok=True)

# List of background image files
bg_files = [str(p) for p in Path(bg_dir).glob('*') if p.suffix.lower() in ['.jpg', '.png', '.jpeg']]

# Load font
try:
    font = ImageFont.truetype(font_path, size=24)
except IOError:
    print(f"Font file not found at {font_path}, using default font.")
    font = ImageFont.load_default()

# Save labels
with open(label_file, 'w', encoding='utf-8') as lf:
    for i in range(num_samples):
        bg_path = random.choice(bg_files)
        img = Image.open(bg_path).convert("RGB").resize(image_size)
        draw = ImageDraw.Draw(img)

        label = ""
        text_to_draw = ""

        if random.random() > noise_ratio:
            # 1. Correct text
            label = correct_text
            text_to_draw = correct_text
        else:
            # 2. Noisy text
            if random.random() < 0.3:
                # 2-1. Random noise characters
                noise_len = random.randint(4, 10)
                label = "".join(random.choices(noise_chars, k=noise_len))
                text_to_draw = label
            else:
                # 2-2. No text noise
                label = ""
                text_to_draw = ""
        # draw text on the image
        if text_to_draw:
            font_size = random.randint(6, 12)
            try:
                font = ImageFont.truetype(font_path, font_size)
            except IOError:
                font = ImageFont.load_default()
            
            text_bbox = draw.textbbox((0, 0), text_to_draw, font=font)
            text_width = text_bbox[2] - text_bbox[0]
            text_height = text_bbox[3] - text_bbox[1]

            x = random.randint(0, image_size[0] - text_width)
            y = random.randint(0, image_size[1] - text_height)
            draw.text((x, y), text_to_draw, fill=(0, 0, 0))

        # Save file
        filename = f"img_{i:05d}.jpg"
        save_path = os.path.join(out_dir, filename)
        img.save(save_path)

        # Record label for OCR
        lf.write(f"{save_path}\t{label}\n")
print(f"Generated {num_samples} images for OCR training ({int(num_samples * (1-noise_ratio))} correct, {int(num_samples * noise_ratio)} noise).")
# Out:
# Generated 1500 images for OCR training (1004 correct, 495 noise).

# %% [markdown]
# ## 2. Data Splitting (Train/Validation)

# %%
from sklearn.model_selection import train_test_split

label_file = "./eco_dataset/labels.txt" 

# Load label list and split 8:2
with open(label_file, encoding="utf-8") as f:
    lines = f.readlines()

train_lines, val_lines = train_test_split(lines, test_size=0.2, random_state=42, shuffle=True)

# Split files
with open("eco_dataset/train_labels.txt", "w", encoding="utf-8") as f:
    f.writelines(train_lines)

with open("eco_dataset/val_labels.txt", "w", encoding="utf-8") as f:
    f.writelines(val_lines)
print(f"Data split into {len(train_lines)} training samples and {len(val_lines)} validation samples.")
# Out:
# Data split into 1200 training samples and 300 validation samples.

# %% [markdown]
# ## 3. CRNN Model Architecture

# %%
import torch.nn as nn
import torchvision.models as models

class CRNN(nn.Module):
    def __init__(self, num_chars, rnn_hidden_size=256, rnn_num_layers=2, dropout=0.5):
        super(CRNN, self).__init__()

        # --- CNN Backbone (Feature Extractor) ---
        # We use ResNet18, but modify it to produce a longer sequence length.
        resnet = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
        # To get a longer sequence, we remove the initial MaxPool layer.
        modules = list(resnet.children())[0:3] + list(resnet.children())[4:-2]
        self.cnn = nn.Sequential(*modules)

        # --- RNN (Sequence Processor) ---
        self.rnn = nn.LSTM(
            input_size=512, # Number of channels from ResNet
            hidden_size=rnn_hidden_size,
            num_layers=rnn_num_layers,
            bidirectional=True,
            dropout=dropout if rnn_num_layers > 1 else 0,
            batch_first=True
        )

        # --- Classifier ---
        self.fc = nn.Linear(rnn_hidden_size * 2, num_chars)

    def forward(self, x):
        # Pass input through the CNN feature extractor.
        features = self.cnn(x) # Shape: (B, C, H, W)

        # Collapse the height dimension by taking the mean across it.
        # This is more ONNX-friendly than AdaptiveAvgPool2d with a `None` dimension.
        features = features.mean(dim=2) # Shape: (B, C, W)
        
        # Prepare for RNN: (B, W, C)
        features = features.permute(0, 2, 1)

        # Pass the feature sequence through the RNN.
        rnn_output, _ = self.rnn(features)

        # Pass the RNN output through the final fully connected classifier.
        output = self.fc(rnn_output)

        # Permute for CTC loss: (Seq, Batch, Classes)
        output = output.permute(1, 0, 2)
        return output

print("CRNN Model class defined. (ONNX export friendly)")
# Out:
# CRNN Model class defined. (ONNX export friendly)

# %% [markdown]
# ## 4. Dataset, DataLoader, and Training Prep

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image

# --- Character Set Definition (Dynamically from labels file) ---
all_chars = set()
with open('./eco_dataset/train_labels.txt', 'r', encoding='utf-8') as f:
    for lin in f:
        try:
            _, text = line.strip().split('\t')
            for char in text:
                all_chars.add(char)
        except ValueError:
            continue

char_set = sorted(list(all_chars))
char_to_int = {char: i + 1 for i, char in enumerate(char_set)}
int_to_char = {i: char for char, i in char_to_int.items()}
num_classes = len(char_set) + 1 # Number of characters + 1 for the blank token in CTC

print(f"Character set: {''.join(char_set)}")
print(f"Number of classes: {num_classes}")

# --- OCR Dataset ---
class OcrDataset(Dataset):
    def __init__(self, label_file, transform=None):
        self.samples = []
        with open(label_file, 'r', encoding='utf-8') as f:
            for line in f:
                path, text = line.strip().split('\t')
                self.samples.append((path, text))
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, text = self.samples[idx]
        image = Image.open(path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        return image, text

# --- Collate Function for CTC ---
def ocr_collate_fn(batch):
    images, texts = zip(*batch)
    images = torch.stack(images, 0)
    
    labels = [torch.tensor([char_to_int[char] for char in text]) for text in texts]
    label_lengths = torch.tensor([len(label) for label in labels])
    padded_labels = torch.nn.utils.rnn.pad_sequence(labels, batch_first=True, padding_value=0)
    
    return images, padded_labels, label_lengths

# --- Transformations for CRNN ---
# A typical height for OCR is 32px.
crnn_transform = transforms.Compose([
    transforms.Resize((32, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# --- Create Datasets and DataLoaders ---
train_dataset = OcrDataset('./eco_dataset/train_labels.txt', transform=crnn_transform)
val_dataset = OcrDataset('./eco_dataset/val_labels.txt', transform=crnn_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=ocr_collate_fn)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=ocr_collate_fn)

print("Datasets and DataLoaders are ready for CRNN training.")
# Out:
# Datasets and DataLoaders are ready for CRNN training.

# %% [markdown]
# ## 5. Model Training and Validation

# %%
import torch.optim as optim
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize model, loss, and optimizer
model = CRNN(num_chars=num_classes).to(device)
criterion = nn.CTCLoss(blank=0, reduction='mean', zero_infinity=True)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

# List to store training history
training_losses = []

print(f"Starting training on {device}...")
for epoch in range(1, 11): # Train for 10 epochs
    model.train()
    train_loss = 0
    for imgs, labels, label_lengths in tqdm(train_loader, desc=f"Epoch {epoch} Training"):
        imgs, labels, label_lengths = imgs.to(device), labels.to(device), label_lengths.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        preds = model(imgs)
        pred_lengths = torch.full(size=(preds.size(1),), fill_value=preds.size(0), dtype=torch.long, device=device)
        
        loss = criterion(preds.log_softmax(2), labels, pred_lengths, label_lengths)
        
        # Backward and optimize
        if not torch.isinf(loss) and not torch.isnan(loss):
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    scheduler.step()
    avg_train_loss = train_loss / len(train_loader)
    training_losses.append(avg_train_loss)
    print(f"Epoch {epoch} | Train Loss: {avg_train_loss:.4f}")

    # Validation
    model.eval()
    print("--- Running Validation ---")
    with torch.no_grad():
        for imgs, labels, label_lengths in val_loader:
            imgs = imgs.to(device)
            preds = model(imgs)
            
            # Simple greedy decoder for a sample
            decoded_preds = torch.argmax(preds.detach().cpu(), dim=2)
            # Take the first item in the batch to show as an example
            pred_text = "".join([int_to_char.get(c.item(), '') for c in decoded_preds[:, 0]]).replace("", "").strip()
            true_text = "".join([int_to_char.get(c.item(), '') for c in labels[0][:label_lengths[0]]])
            
            print(f"Sample Prediction: '{pred_text}' | True Label: '{true_text}'")
            break # Show only one batch for brevity

print("Training finished.")
# Out:
# Starting training on cuda...
# Epoch 1 Training: 100%|██████████| 25/25 [00:14<00:00,  1.70it/s]
# Epoch 1 | Train Loss: 0.3580
# --- Running Validation ---
# Sample Prediction: 'ECCOOQQCCOODEE' | True Label: 'ECOQCODE'
# Epoch 2 Training: 100%|██████████| 25/25 [00:04<00:00,  5.86it/s]
# Epoch 2 | Train Loss: 0.0006
# --- Running Validation ---
# Sample Prediction: 'EECOOQQCCODDEE' | True Label: 'ECOQCODE'
# Epoch 3 Training: 100%|██████████| 25/25 [00:04<00:00,  5.43it/s]
# Epoch 3 | Train Loss: 0.0002
# --- Running Validation ---
# Sample Prediction: 'ECCOOQQCCODDEE' | True Label: 'ECOQCODE'
# Epoch 4 Training: 100%|██████████| 25/25 [00:05<00:00,  4.28it/s]
# Epoch 4 | Train Loss: 0.0002
# --- Running Validation ---
# Sample Prediction: 'ECCOOQQCCODDEE' | True Label: 'ECOQCODE'
# Epoch 5 Training: 100%|██████████| 25/25 [00:05<00:00,  4.87it/s]
# Epoch 5 | Train Loss: 0.0001
# --- Running Validation ---
# Sample Prediction: 'ECCOOQQCCODDEE' | True Label: 'ECOQCODE'
# ...

# %% [markdown]
# ## 6. Training Results Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(training_losses, label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Inference on New Images

# %%
import matplotlib.pyplot as plt
from PIL import Image

# --- Greedy Decoder for single inference ---
def decode_inference_prediction(preds, int_to_char_map):
    # Squeeze the batch dimension before processing
    preds = preds.squeeze(1)
    pred_indices = torch.argmax(preds, dim=1) # Now shape is (Seq, Classes)
    
    # Remove consecutive duplicates and blank tokens (0)
    text = []
    for i, idx in enumerate(pred_indices):
        if idx == 0: # blank token
            continue
        if i > 0 and idx == pred_indices[i-1]: # repeated token
            continue
        text.append(int_to_char_map.get(idx.item(), ''))
    return "".join(text)

def run_inference(image_path, model, transform, device, int_to_char_map):
    # Load and transform the image
    image = Image.open(image_path).convert("RGB")
    transformed_image = transform(image).unsqueeze(0) # Add batch dimension
    
    # Set model to evaluation mode and predict
    model.eval()
    with torch.no_grad():
        preds = model(transformed_image.to(device))
        pred_text = decode_inference_prediction(preds.cpu(), int_to_char_map)
    
    # Display the image and the prediction
    plt.imshow(image)
    plt.title(f"Prediction: {pred_text}")
    plt.axis('off')
    plt.show()

import glob

image_paths_to_test = glob.glob('./eco_dataset/images/*.jpg')

if image_paths_to_test:
    for image_path in image_paths_to_test[:10]:
        print(f"Running inference on: {image_path}")
        run_inference(image_path, model, crnn_transform, device, int_to_char)
else:
    print("No images found in the specified directory for inference.")
# Out:
# Running inference on: ./eco_dataset/images\img_00000.jpg
# Running inference on: ./eco_dataset/images\img_00001.jpg
# Running inference on: ./eco_dataset/images\img_00002.jpg
# Running inference on: ./eco_dataset/images\img_00003.jpg
# Running inference on: ./eco_dataset/images\img_00004.jpg
# Running inference on: ./eco_dataset/images\img_00005.jpg
# Running inference on: ./eco_dataset/images\img_00006.jpg
# Running inference on: ./eco_dataset/images\img_00007.jpg
# Running inference on: ./eco_dataset/images\img_00008.jpg
# Running inference on: ./eco_dataset/images\img_00009.jpg

# %% [markdown]
# ## 8. Final Evaluation and ONNX Export

# %%
# --- Simple Greedy Decoder for Evaluation ---
def decode_preds(preds):
    decoded_texts = []
    pred_indices = torch.argmax(preds, dim=2) # Get the character with max probability
    pred_indices = pred_indices.permute(1, 0) # -> (Batch, Seq)
    
    for indices in pred_indices:
        text = []
        # Remove consecutive duplicates and blank tokens
        for i, idx in enumerate(indices):
            if idx == 0: # blank token
                continue
            if i > 0 and idx == indices[i-1]: # repeated token
                continue
            text.append(int_to_char.get(idx.item(), ''))
        decoded_texts.append("".join(text))
    return decoded_texts

# --- Full Evaluation ---
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for imgs, labels, label_lengths in val_loader:
        preds = model(imgs.to(device))
        decoded_predictions = decode_preds(preds.cpu())
        all_preds.extend(decoded_predictions)
        
        for i in range(labels.size(0)):
            true_text = "".join([int_to_char.get(c.item(), '') for c in labels[i][:label_lengths[i]]])
            all_labels.append(true_text)

correct_predictions = sum(1 for pred, true in zip(all_preds, all_labels) if pred == true)
accuracy = correct_predictions / len(all_labels) if all_labels else 0
print(f"Validation Accuracy (Exact Match): {accuracy * 100:.2f}%")
print("--- Sample Predictions vs True Labels ---")
for i in range(min(5, len(all_preds))):
    print(f"Pred: '{all_preds[i]}' | True: '{all_labels[i]}'")

# --- Export to ONNX ---
output_onnx_path = "ecoq_crnn_ocr.onnx"
# Dummy input with dynamic batch size and width
dummy_input = torch.randn(1, 3, 32, 224).to(device)

torch.onnx.export(model,
                  dummy_input,
                  output_onnx_path,
                  export_params=True,
                  opset_version=11,
                  do_constant_folding=True,
                  input_names=['input'],
                  output_names=['output'],
                  dynamic_axes={'input' : {0 : 'batch_size', 3: 'width'},
                                'output' : {1 : 'batch_size'}})

print(f"Model successfully exported to {output_onnx_path}")
# Out:
# Validation Accuracy (Exact Match): 100.00%
# --- Sample Predictions vs True Labels ---
# Pred: 'ECOQCODE' | True: 'ECOQCODE'
# Pred: 'ECOQCODE' | True: 'ECOQCODE'
# Pred: 'ECOQCODE' | True: 'ECOQCODE'
# Pred: 'ECOQCODE' | True: 'ECOQCODE'
# Pred: 'ECOQCODE' | True: 'ECOQCODE'
# c:\Users\seoks\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\onnx\symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# Model successfully exported to ecoq_crnn_ocr.onnx

# %% [markdown]
# ## 9. Make nois data to test

# %%
import os
import random
from PIL import Image, ImageDraw, ImageFont
from pathlib import Path

# Configuration
bg_dir = './real_backgrounds'
out_dir = './noisy_dataset/images'
font_path = 'arial.ttf'  # Make sure this font is available or change the path
text = 'Error'
num_samples = 10  # Number of images to generate
image_size = (648, 648)  # Output image size

os.makedirs(out_dir, exist_ok=True)

# List of background image files
bg_files = [str(p) for p in Path(bg_dir).glob('*') if p.suffix.lower() in ['.jpg', '.png', '.jpeg']]

# Load font
try:
    font = ImageFont.truetype(font_path, size=24)
except IOError:
    print(f"Font file not found at {font_path}, using default font.")
    font = ImageFont.load_default()

# Save labels
with open(label_file, 'w', encoding='utf-8') as lf:
    for i in range(num_samples):
        bg_path = random.choice(bg_files)
        img = Image.open(bg_path).convert("RGB").resize(image_size)
        draw = ImageDraw.Draw(img)

        # For OCR, the label is the text itself.
        # We will add text to every image for this training.
        label = text

        # Determine text size
        font_size = random.randint(6, 12)
        try:
            font = ImageFont.truetype(font_path, font_size)
        except IOError:
            font = ImageFont.load_default()
        
        text_bbox = draw.textbbox((0, 0), text, font=font)
        text_width = text_bbox[2] - text_bbox[0]
        text_height = text_bbox[3] - text_bbox[1]

        if text_width < image_size[0] and text_height < image_size[1]:
            x = random.randint(0, image_size[0] - text_width)
            y = random.randint(0, image_size[1] - text_height)
            draw.text((x, y), text, font=font, fill=(0, 0, 0)) # Black text
        
        # Save file
        filename = f"img_{i:05d}.jpg"
        save_path = os.path.join(out_dir, filename)
        img.save(save_path)

        # Record label for OCR
        lf.write(f"{save_path}\t{label}\n")
print(f"Generated {num_samples} images for OCR training.")
# Out:
# Generated 10 images for OCR training.

# %% [markdown]
# ## 10. Test with Noisy data

# %%
import matplotlib.pyplot as plt
from PIL import Image

# --- Greedy Decoder for single inference ---
def decode_inference_prediction(preds, int_to_char_map):
    # Squeeze the batch dimension before processing
    preds = preds.squeeze(1)
    pred_indices = torch.argmax(preds, dim=1) # Now shape is (Seq, Classes)
    
    # Remove consecutive duplicates and blank tokens (0)
    text = []
    for i, idx in enumerate(pred_indices):
        if idx == 0: # blank token
            continue
        if i > 0 and idx == pred_indices[i-1]: # repeated token
            continue
        text.append(int_to_char_map.get(idx.item(), ''))
    return "".join(text)

def run_inference(image_path, model, transform, device, int_to_char_map):
    # Load and transform the image
    image = Image.open(image_path).convert("RGB")
    transformed_image = transform(image).unsqueeze(0) # Add batch dimension
    
    # Set model to evaluation mode and predict
    model.eval()
    with torch.no_grad():
        preds = model(transformed_image.to(device))
        pred_text = decode_inference_prediction(preds.cpu(), int_to_char_map)
    
    # Display the image and the prediction
    plt.imshow(image)
    plt.title(f"Prediction: {pred_text}")
    plt.axis('off')
    plt.show()

import glob

image_paths_to_test = glob.glob('./eco_dataset/images/*.jpg')
image_paths_to_test_noisy = glob.glob('./noisy_dataset/images/*.jpg')

if image_paths_to_test:
    for image_path in image_paths_to_test[:10]:
        print(f"Running inference on: {image_path}")
        run_inference(image_path, model, crnn_transform, device, int_to_char)
else:
    print("No images found in the specified directory for inference.")

if image_paths_to_test_noisy:
    for image_path in image_paths_to_test_noisy[:10]:
        print(f"Running inference on: {image_path}")
        run_inference(image_path, model, crnn_transform, device, int_to_char)
else:
    print("No noisy images found in the specified directory for inference.")
# Out:
# Running inference on: ./eco_dataset/images\img_00000.jpg
# Running inference on: ./eco_dataset/images\img_00001.jpg
# Running inference on: ./eco_dataset/images\img_00002.jpg
# Running inference on: ./eco_dataset/images\img_00003.jpg
# Running inference on: ./eco_dataset/images\img_00004.jpg
# Running inference on: ./eco_dataset/images\img_00005.jpg
# Running inference on: ./eco_dataset/images\img_00006.jpg
# Running inference on: ./eco_dataset/images\img_00007.jpg
# Running inference on: ./eco_dataset/images\img_00008.jpg
# Running inference on: ./eco_dataset/images\img_00009.jpg
# Running inference on: ./noisy_dataset/images\img_00000.jpg
# Running inference on: ./noisy_dataset/images\img_00001.jpg
# Running inference on: ./noisy_dataset/images\img_00002.jpg
# Running inference on: ./noisy_dataset/images\img_00003.jpg
# Running inference on: ./noisy_dataset/images\img_00004.jpg
# Running inference on: ./noisy_dataset/images\img_00005.jpg
# ...
